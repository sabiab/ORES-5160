# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/CDC Diabetes Survillience burden percentage (2001-2020).csv")
data
# Out:
#        CountyFIPS             County    State        Country State Code  Year  \
# 0            1001     Autauga County  Alabama  United States         Al  2004
# 1            1003     Baldwin County  Alabama  United States         Al  2004
# 2            1005     Barbour County  Alabama  United States         Al  2004
# 3            1007        Bibb County  Alabama  United States         Al  2004
# 4            1009      Blount County  Alabama  United States         Al  2004
# ...           ...                ...      ...            ...        ...   ...
# 53545       56037  Sweetwater County  Wyoming            NaN        NaN  2020
# 53546       56039       Teton County  Wyoming            NaN        NaN  2020
# 53547       56041       Uinta County  Wyoming            NaN        NaN  2020
# 53548       56043    Washakie County  Wyoming            NaN        NaN  2020
# 53549       56045      Weston County  Wyoming            NaN        NaN  2020
#
# ...

# %%
data.drop_duplicates()
# Out:
#        CountyFIPS             County    State        Country State Code  Year  \
# 0            1001     Autauga County  Alabama  United States         Al  2004
# 1            1003     Baldwin County  Alabama  United States         Al  2004
# 2            1005     Barbour County  Alabama  United States         Al  2004
# 3            1007        Bibb County  Alabama  United States         Al  2004
# 4            1009      Blount County  Alabama  United States         Al  2004
# ...           ...                ...      ...            ...        ...   ...
# 53545       56037  Sweetwater County  Wyoming            NaN        NaN  2020
# 53546       56039       Teton County  Wyoming            NaN        NaN  2020
# 53547       56041       Uinta County  Wyoming            NaN        NaN  2020
# 53548       56043    Washakie County  Wyoming            NaN        NaN  2020
# 53549       56045      Weston County  Wyoming            NaN        NaN  2020
#
# ...

# %%
 df = data.drop(columns = "Country")
 df
# Out:
#        CountyFIPS             County    State State Code  Year  Percentage  \
# 0            1001     Autauga County  Alabama         Al  2004         7.4
# 1            1003     Baldwin County  Alabama         Al  2004         6.5
# 2            1005     Barbour County  Alabama         Al  2004         7.2
# 3            1007        Bibb County  Alabama         Al  2004         6.8
# 4            1009      Blount County  Alabama         Al  2004         6.6
# ...           ...                ...      ...        ...   ...         ...
# 53545       56037  Sweetwater County  Wyoming        NaN  2020      2368.0
# 53546       56039       Teton County  Wyoming        NaN  2020       857.0
# 53547       56041       Uinta County  Wyoming        NaN  2020      1163.0
# 53548       56043    Washakie County  Wyoming        NaN  2020       588.0
# 53549       56045      Weston County  Wyoming        NaN  2020       461.0
#
#        Lower Limit  Upper Limit
# 0              5.2         10.0
# ...

# %%
df1 = df.drop(columns = "State Code")
df1
# Out:
#        CountyFIPS             County    State  Year  Percentage  Lower Limit  \
# 0            1001     Autauga County  Alabama  2004         7.4          5.2
# 1            1003     Baldwin County  Alabama  2004         6.5          4.9
# 2            1005     Barbour County  Alabama  2004         7.2          5.2
# 3            1007        Bibb County  Alabama  2004         6.8          4.8
# 4            1009      Blount County  Alabama  2004         6.6          4.8
# ...           ...                ...      ...   ...         ...          ...
# 53545       56037  Sweetwater County  Wyoming  2020      2368.0       1770.0
# 53546       56039       Teton County  Wyoming  2020       857.0        560.0
# 53547       56041       Uinta County  Wyoming  2020      1163.0        841.0
# 53548       56043    Washakie County  Wyoming  2020       588.0        413.0
# 53549       56045      Weston County  Wyoming  2020       461.0        312.0
#
#        Upper Limit
# 0             10.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53550 entries, 0 to 53549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CountyFIPS   53550 non-null  int64
#  1   County       53550 non-null  object
#  2   State        53550 non-null  object
#  3   Year         53550 non-null  int64
#  4   Percentage   53391 non-null  float64
#  5   Lower Limit  53391 non-null  float64
#  6   Upper Limit  53391 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 2.9+ MB

# %%
df1['State'] = df1['State'].astype('category')
df1['County'] = df1['County'].astype('category')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53550 entries, 0 to 53549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CountyFIPS   53550 non-null  int64
#  1   County       53550 non-null  category
#  2   State        53550 non-null  category
#  3   Year         53550 non-null  int64
#  4   Percentage   53391 non-null  float64
#  5   Lower Limit  53391 non-null  float64
#  6   Upper Limit  53391 non-null  float64
# dtypes: category(2), float64(3), int64(2)
# memory usage: 2.3 MB

# %%
df1.isna().sum()
# Out:
# CountyFIPS       0
# County           0
# State            0
# Year             0
# Percentage     159
# Lower Limit    159
# Upper Limit    159
# dtype: int64

# %%
df2 = df1.dropna()
df2
# Out:
#        CountyFIPS             County    State  Year  Percentage  Lower Limit  \
# 0            1001     Autauga County  Alabama  2004         7.4          5.2
# 1            1003     Baldwin County  Alabama  2004         6.5          4.9
# 2            1005     Barbour County  Alabama  2004         7.2          5.2
# 3            1007        Bibb County  Alabama  2004         6.8          4.8
# 4            1009      Blount County  Alabama  2004         6.6          4.8
# ...           ...                ...      ...   ...         ...          ...
# 53545       56037  Sweetwater County  Wyoming  2020      2368.0       1770.0
# 53546       56039       Teton County  Wyoming  2020       857.0        560.0
# 53547       56041       Uinta County  Wyoming  2020      1163.0        841.0
# 53548       56043    Washakie County  Wyoming  2020       588.0        413.0
# 53549       56045      Weston County  Wyoming  2020       461.0        312.0
#
#        Upper Limit
# 0             10.0
# ...

# %%
df3 = df2.rename(columns = {
    "CountyFIPS" : "FIPS CODE",
    "Lower Limit" : "Lower Confidence Limit",
    "Upper Limit" : "Upper Confidence Limit"
 })
df3
# Out:
#        FIPS CODE             County    State  Year  Percentage  \
# 0           1001     Autauga County  Alabama  2004         7.4
# 1           1003     Baldwin County  Alabama  2004         6.5
# 2           1005     Barbour County  Alabama  2004         7.2
# 3           1007        Bibb County  Alabama  2004         6.8
# 4           1009      Blount County  Alabama  2004         6.6
# ...          ...                ...      ...   ...         ...
# 53545      56037  Sweetwater County  Wyoming  2020      2368.0
# 53546      56039       Teton County  Wyoming  2020       857.0
# 53547      56041       Uinta County  Wyoming  2020      1163.0
# 53548      56043    Washakie County  Wyoming  2020       588.0
# 53549      56045      Weston County  Wyoming  2020       461.0
#
#        Lower Confidence Limit  Upper Confidence Limit
# 0                         5.2                    10.0
# 1                         4.9                     8.2
# ...

# %%
df3['Confidence Limit'] = df3['Upper Confidence Limit'] - df3['Lower Confidence Limit']
df3
# Out:
#        FIPS CODE             County    State  Year  Percentage  \
# 0           1001     Autauga County  Alabama  2004         7.4
# 1           1003     Baldwin County  Alabama  2004         6.5
# 2           1005     Barbour County  Alabama  2004         7.2
# 3           1007        Bibb County  Alabama  2004         6.8
# 4           1009      Blount County  Alabama  2004         6.6
# ...          ...                ...      ...   ...         ...
# 53545      56037  Sweetwater County  Wyoming  2020      2368.0
# 53546      56039       Teton County  Wyoming  2020       857.0
# 53547      56041       Uinta County  Wyoming  2020      1163.0
# 53548      56043    Washakie County  Wyoming  2020       588.0
# 53549      56045      Weston County  Wyoming  2020       461.0
#
#        Lower Confidence Limit  Upper Confidence Limit  Confidence Limit
# 0                         5.2                    10.0               4.8
# ...

# %%
df3.drop_duplicates()
# Out:
#        FIPS CODE             County    State  Year  Percentage  \
# 0           1001     Autauga County  Alabama  2004         7.4
# 1           1003     Baldwin County  Alabama  2004         6.5
# 2           1005     Barbour County  Alabama  2004         7.2
# 3           1007        Bibb County  Alabama  2004         6.8
# 4           1009      Blount County  Alabama  2004         6.6
# ...          ...                ...      ...   ...         ...
# 53545      56037  Sweetwater County  Wyoming  2020      2368.0
# 53546      56039       Teton County  Wyoming  2020       857.0
# 53547      56041       Uinta County  Wyoming  2020      1163.0
# 53548      56043    Washakie County  Wyoming  2020       588.0
# 53549      56045      Weston County  Wyoming  2020       461.0
#
#        Lower Confidence Limit  Upper Confidence Limit  Confidence Limit
# 0                         5.2                    10.0               4.8
# ...

# %%
sns.boxplot(df3['Percentage'])
# Out:
# <Axes: >

# %%
Q1 = df3['Percentage'].quantile(0.25)
Q3 = df3['Percentage'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df3[(df3['Percentage'] < lower_bound) | (df3['Percentage'] > upper_bound)]
outliers
# Out:
#        FIPS CODE             County           State  Year  Percentage  \
# 5089       37087     Haywood County  North Carolina  2005        13.3
# 7730       28047    Harrison County     Mississippi  2006        14.3
# 7746       28079       Leake County     Mississippi  2006        13.0
# 8239       37087     Haywood County  North Carolina  2006        14.2
# 9320       54041       Lewis County   West Virginia  2006        13.0
# ...          ...                ...             ...   ...         ...
# 53545      56037  Sweetwater County         Wyoming  2020      2368.0
# 53546      56039       Teton County         Wyoming  2020       857.0
# 53547      56041       Uinta County         Wyoming  2020      1163.0
# 53548      56043    Washakie County         Wyoming  2020       588.0
# 53549      56045      Weston County         Wyoming  2020       461.0
#
#        Lower Confidence Limit  Upper Confidence Limit  Confidence Limit
# ...

# %%
df4 = df3[~((df3['Percentage'] < lower_bound) | (df3['Percentage'] > upper_bound))]
df4
# Out:
#        FIPS CODE             County    State  Year  Percentage  \
# 0           1001     Autauga County  Alabama  2004         7.4
# 1           1003     Baldwin County  Alabama  2004         6.5
# 2           1005     Barbour County  Alabama  2004         7.2
# 3           1007        Bibb County  Alabama  2004         6.8
# 4           1009      Blount County  Alabama  2004         6.6
# ...          ...                ...      ...   ...         ...
# 50394      56035    Sublette County  Wyoming  2019         4.2
# 50395      56037  Sweetwater County  Wyoming  2019         7.3
# 50396      56039       Teton County  Wyoming  2019         8.8
# 50397      56041       Uinta County  Wyoming  2019         8.1
# 50954      15005     Kalawao County   Hawaii  2020        12.0
#
#        Lower Confidence Limit  Upper Confidence Limit  Confidence Limit
# 0                         5.2                    10.0               4.8
# ...

# %%
df4.to_csv("CDC_Updated.csv", index=False)
